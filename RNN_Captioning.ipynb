# %% [markdown]
# # Image Captioning with RNNs
# In this exercise you will implement a vanilla recurrent neural networks and use them it to train a model that can generate novel captions for images.

# %%
# As usual, a bit of setup
from __future__ import print_function
import time, os, json
import numpy as np
import matplotlib.pyplot as plt

from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.rnn_layers import *
from cs231n.captioning_solver import CaptioningSolver
from cs231n.classifiers.rnn import CaptioningRNN
from cs231n.coco_utils import load_coco_data, sample_coco_minibatch, decode_captions
from cs231n.image_utils import image_from_url

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# ## Install h5py
# The COCO dataset we will be using is stored in HDF5 format. To load HDF5 files, we will need to install the `h5py` Python package. From the command line, run: <br/>
# `pip install h5py`  <br/>
# If you receive a permissions error, you may need to run the command as root: <br/>
# ```sudo pip install h5py```
#
# You can also run commands directly from the Jupyter notebook by prefixing the command with the "!" character:

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in c:\programdata\anaconda3\envs\tensorflow\lib\site-packages
# Requirement already satisfied: numpy>=1.7 in c:\programdata\anaconda3\envs\tensorflow\lib\site-packages (from h5py)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\tensorflow\lib\site-packages (from h5py)

# %% [markdown]
# # Microsoft COCO
# For this exercise we will use the 2014 release of the [Microsoft COCO dataset](http://mscoco.org/) which has become the standard testbed for image captioning. The dataset consists of 80,000 training images and 40,000 validation images, each annotated with 5 captions written by workers on Amazon Mechanical Turk.
#
# You should have already downloaded the data by changing to the `cs231n/datasets` directory and running the script `get_assignment3_data.sh`. If you haven't yet done so, run that script now. Warning: the COCO data download is ~1GB.
#
# We have preprocessed the data and extracted features for you already. For all images we have extracted features from the fc7 layer of the VGG-16 network pretrained on ImageNet; these features are stored in the files `train2014_vgg16_fc7.h5` and `val2014_vgg16_fc7.h5` respectively. To cut down on processing time and memory requirements, we have reduced the dimensionality of the features from 4096 to 512; these features can be found in the files `train2014_vgg16_fc7_pca.h5` and `val2014_vgg16_fc7_pca.h5`.
#
# The raw images take up a lot of space (nearly 20GB) so we have not included them in the download. However all images are taken from Flickr, and URLs of the training and validation images are stored in the files `train2014_urls.txt` and `val2014_urls.txt` respectively. This allows you to download images on the fly for visualization. Since images are downloaded on-the-fly, **you must be connected to the internet to view images**.
#
# Dealing with strings is inefficient, so we will work with an encoded version of the captions. Each word is assigned an integer ID, allowing us to represent a caption by a sequence of integers. The mapping between integer IDs and words is in the file `coco2014_vocab.json`, and you can use the function `decode_captions` from the file `cs231n/coco_utils.py` to convert numpy arrays of integer IDs back into strings.
#
# There are a couple special tokens that we add to the vocabulary. We prepend a special `<START>` token and append an `<END>` token to the beginning and end of each caption respectively. Rare words are replaced with a special `<UNK>` token (for "unknown"). In addition, since we want to train with minibatches containing captions of different lengths, we pad short captions with a special `<NULL>` token after the `<END>` token and don't compute loss or gradient for `<NULL>` tokens. Since they are a bit of a pain, we have taken care of all implementation details around special tokens for you.
#
# You can load all of the MS-COCO data (captions, features, URLs, and vocabulary) using the `load_coco_data` function from the file `cs231n/coco_utils.py`. Run the following cell to do so:

# %%
# Load COCO data from disk; this returns a dictionary
# We'll work with dimensionality-reduced features for this notebook, but feel
# free to experiment with the original features by changing the flag below.
data = load_coco_data(pca_features=True)

# Print out all the keys and values from the data dictionary
for k, v in data.items():
    if type(v) == np.ndarray:
        print(k, type(v), v.shape, v.dtype)
    else:
        print(k, type(v), len(v))
# Out:
# val_captions <class 'numpy.ndarray'> (195954, 17) int32
# train_captions <class 'numpy.ndarray'> (400135, 17) int32
# train_urls <class 'numpy.ndarray'> (82783,) <U63
# train_features <class 'numpy.ndarray'> (82783, 512) float32
# val_features <class 'numpy.ndarray'> (40504, 512) float32
# word_to_idx <class 'dict'> 1004
# val_image_idxs <class 'numpy.ndarray'> (195954,) int32
# idx_to_word <class 'list'> 1004
# train_image_idxs <class 'numpy.ndarray'> (400135,) int32
# val_urls <class 'numpy.ndarray'> (40504,) <U63

# %%
data['val_captions'][0]
# Out:
# array([  1,   4, 349,   3,   9,   4,  91, 124,   7,  41,   3,   2,   0,
#          0,   0,   0,   0])

# %%
data['train_urls'][0]
# Out:
# 'http://farm4.staticflickr.com/3153/2970773875_164f0c0b83_z.jpg'

# %%
data['train_image_idxs'][100]
# Out:
# 77871

# %%
data['train_features'][0]
# Out:
# array([ -1.34303713e+01,  -4.47964430e-01,  -1.09597516e+00,
#          6.02133632e-01,   1.24304752e+01,   2.59842324e+00,
#          2.86871552e+00,  -5.14839268e+00,  -5.36816740e+00,
#          1.13996143e+01,  -3.21550131e+00,   5.47932816e+00,
#         -6.77553892e+00,   7.97219563e+00,  -1.33905067e+01,
#         -7.00287914e+00,   2.79851985e+00,   1.83838165e+00,
#          2.98779416e+00,  -3.83734703e+00,   8.15812492e+00,
#         -2.22802326e-01,  -4.61995929e-01,  -6.26737165e+00,
#          1.05291176e+01,  -3.50549310e-01,   6.90953875e+00,
#          2.44243532e-01,  -3.70114446e+00,   4.83804369e+00,
#         -8.40624046e+00,  -1.04452801e+01,   8.71168041e+00,
#          8.13083076e+00,  -5.24823785e-01,  -2.84213758e+00,
#          4.25392008e+00,  -6.74198294e+00,  -1.27799428e+00,
#         -2.81341791e+00,   2.65694427e+00,  -8.91349137e-01,
#         -1.44591331e+00,   5.07545757e+00,  -4.85347986e+00,
#          1.44414091e+00,   5.44516897e+00,   8.13720882e-01,
#          4.36985493e+00,  -2.75205946e+00,   3.95019031e+00,
#         -3.23487139e+00,  -2.30146837e+00,   5.73137093e+00,
#          3.43614411e+00,   6.62349319e+00,  -3.15358728e-01,
#         -2.66669393e+00,   5.00422049e+00,  -2.32653952e+00,
#         -4.06551933e+00,   2.31495097e-01,  -3.77738357e+00,
#         -7.89504480e+00,  -1.65257430e+00,   4.47138071e-01,
#          2.26078749e+00,   3.36710620e+00,   5.83480310e+00,
#          6.73637199e+00,   4.27977276e+00,  -2.85577178e+00,
#         -2.50540304e+00,  -2.79353404e+00,  -1.73036087e+00,
#         -6.77825356e+00,  -2.09175062e+00,   3.77505994e+00,
#          3.31233549e+00,  -5.85355163e-01,   2.28589272e+00,
#         -6.98970890e+00,   6.12946749e-01,   2.02621102e-01,
#         -6.99034214e-01,   1.25797176e+00,   3.32012653e-01,
#          6.27035189e+00,   1.81399453e+00,   4.49032545e+00,
#         -5.36556196e+00,   2.52691078e+00,  -2.08015025e-01,
#         -2.49123240e+00,  -8.90949130e-01,  -9.23020720e-01,
#          2.01145434e+00,  -7.89171219e-01,  -5.35975575e-01,
#          2.15780807e+00,  -3.16929674e+00,   2.95501447e+00,
#          3.99173570e+00,   2.36390543e+00,  -3.85776424e+00,
#         -1.35748279e+00,   2.80631185e-01,  -5.56985080e-01,
#         -6.67791188e-01,   1.36014485e+00,   1.76534891e+00,
#         -1.53141618e+00,   2.27486086e+00,  -1.09758353e+00,
#          9.26083744e-01,  -3.39924783e-01,  -1.59309947e+00,
#          8.99213135e-01,  -4.10544090e-02,  -6.79370314e-02,
#         -2.25316226e-01,   1.04373646e+00,  -2.37794256e+00,
#         -7.58570671e-01,  -5.93062401e-01,  -3.19237232e-01,
#         -6.46001697e-02,   1.66749692e+00,   1.44812512e+00,
#          5.97013056e-01,   8.44447196e-01,   3.09553146e-01,
#          3.32724452e-01,   1.40496206e+00,   6.58181190e-01,
#         -1.65218616e+00,  -7.37245083e-02,   4.76642609e-01,
#         -3.29008698e-01,   5.61344028e-01,  -2.31809402e+00,
#         -2.05937791e+00,  -8.26396525e-01,   1.23307168e+00,
#          3.03921074e-01,   1.31636083e+00,   2.06275678e+00,
#         -1.13745123e-01,  -8.45701814e-01,  -9.34544504e-02,
#          1.35978115e+00,   2.02403140e+00,   6.43314719e-01,
#         -1.03679568e-01,  -6.64473027e-02,   1.53735471e+00,
#          8.54330778e-01,   4.94375348e-01,   5.50659895e-01,
#          1.92159474e-01,   1.71819401e+00,   1.15367800e-01,
#         -2.19827592e-02,  -1.97801352e-01,  -1.26857236e-02,
#         -1.11083314e-01,   2.30449009e+00,  -5.47880411e-01,
#          1.17108870e+00,   8.78205299e-01,  -2.08309102e+00,
#         -3.82741332e-01,   1.02018106e+00,   6.55998290e-02,
#         -7.82153070e-01,   5.50513744e-01,  -1.99947089e-01,
#         -1.69834352e+00,   1.57867923e-01,   1.21624887e+00,
#         -6.37261510e-01,  -2.60681510e+00,  -5.84347010e-01,
#         -2.61908442e-01,  -8.44476283e-01,   5.06736159e-01,
#         -6.80039167e-01,  -8.62269580e-01,  -6.94671929e-01,
#         -4.17217374e-01,   4.48916078e-01,   6.86084926e-01,
#          6.20028526e-02,  -8.78446460e-01,  -9.66747999e-01,
#         -3.11467826e-01,   1.04306257e+00,   7.92209208e-01,
#          2.05581236e+00,   4.79871422e-01,  -6.39556885e-01,
#          3.45237374e-01,  -2.17215919e+00,  -5.49645185e-01,
#         -7.17974424e-01,  -1.25543177e+00,   3.90750974e-01,
#          3.50532800e-01,   8.58520389e-01,  -4.15783346e-01,
#          1.41939974e+00,   1.17292035e+00,  -1.42986965e+00,
#         -1.40461564e+00,   7.33537614e-01,   1.31583345e+00,
#         -1.47146225e-01,  -5.11510134e-01,   1.33545446e+00,
#         -4.86487657e-01,  -1.75690866e+00,   1.42241836e+00,
#          9.45830107e-01,  -1.61582589e-01,   7.68496752e-01,
#         -1.35878074e+00,   1.16377130e-01,  -1.56991661e+00,
#          9.83866811e-01,  -1.96988463e+00,  -3.02874565e-01,
#          3.87840211e-01,  -8.12083542e-01,   4.63810861e-01,
#         -1.26738024e+00,   2.23368406e-03], dtype=float32)

# %%
data['idx_to_word'][0]
# Out:
# '<NULL>'

# %%
data['word_to_idx']
# Out:
# {'looks': 288,
#  'mounted': 614,
#  'giant': 707,
#  'sun': 511,
#  'posing': 292,
#  'before': 843,
#  'watch': 475,
#  'paper': 328,
#  'crossing': 457,
#  'having': 536,
#  'beneath': 953,
#  'adults': 795,
#  'donuts': 403,
#  'bears': 339,
#  'seen': 472,
#  'palm': 978,
#  'a': 4,
#  'asian': 749,
#  'counter': 185,
#  'watching': 285,
#  'alone': 681,
#  'people': 19,
#  'hard': 997,
#  'male': 367,
#  'bushes': 697,
#  'baseball': 53,
#  'surfer': 364,
#  'snowboarder': 503,
#  'plate': 43,
#  'persons': 752,
#  'monitor': 463,
#  'stop': 149,
#  'gets': 936,
#  'throwing': 447,
#  'animal': 370,
#  'dish': 505,
#  'just': 573,
#  'basket': 574,
#  'roof': 892,
#  'sunset': 871,
#  'house': 332,
#  'pepperoni': 932,
#  'island': 994,
#  'pointing': 865,
#  'poles': 637,
#  'horses': 192,
#  'hanging': 257,
#  'backpack': 764,
#  'onions': 816,
#  'playing': 57,
#  'cabinets': 428,
#  'narrow': 903,
#  'racing': 980,
#  'team': 791,
#  'waiting': 338,
#  'gold': 934,
#  'lush': 476,
#  'graze': 877,
#  'oven': 282,
#  'water': 52,
#  'way': 410,
#  'standing': 17,
#  'peppers': 971,
#  'airport': 286,
#  'red': 48,
#  'stove': 291,
#  'cake': 110,
#  'underneath': 527,
#  'giving': 948,
#  'into': 151,
#  'suitcases': 710,
#  'beach': 76,
#  'jump': 604,
#  'coat': 856,
#  'restaurant': 341,
#  'knife': 397,
#  'passenger': 360,
#  'purple': 435,
#  'remote': 352,
#  'leather': 962,
#  'pulled': 670,
#  'legs': 728,
#  'passengers': 613,
#  'dog': 47,
#  'bag': 391,
#  'scene': 466,
#  'sides': 916,
#  'smoke': 931,
#  'end': 621,
#  'leaves': 493,
#  'time': 542,
#  'side': 69,
#  'they': 579,
#  'gate': 819,
#  'clothes': 696,
#  'public': 509,
#  'set': 316,
#  'bathroom': 58,
#  'among': 807,
#  'vases': 550,
#  'surrounded': 400,
#  'vanity': 977,
#  'lunch': 855,
#  'shade': 945,
#  'lake': 421,
#  'toddler': 824,
#  'over': 93,
#  'off': 214,
#  'trains': 589,
#  '<NULL>': 0,
#  'feet': 678,
#  'white': 22,
#  'cell': 176,
#  'broken': 840,
#  'cloth': 913,
#  'doing': 256,
#  'surfers': 747,
#  'sauce': 554,
#  'himself': 898,
#  'containers': 989,
#  'plates': 307,
#  'sticking': 730,
#  'bottles': 658,
#  'computer': 118,
#  'lots': 322,
#  'rocky': 827,
#  'donut': 520,
#  'yellow': 113,
#  'long': 249,
#  'branch': 552,
#  'chairs': 287,
#  'sofa': 666,
#  'vegetables': 210,
#  'crowded': 665,
#  'round': 767,
#  'eating': 109,
#  'batter': 394,
#  'flock': 845,
#  'sunglasses': 779,
#  'tiled': 597,
#  'be': 333,
#  'young': 49,
#  'wild': 744,
#  'girls': 433,
#  'sliced': 672,
#  'along': 221,
#  'shop': 627,
#  'turn': 869,
#  'pink': 255,
#  'items': 356,
#  'dessert': 737,
#  'board': 116,
#  'tennis': 39,
#  'machine': 880,
#  '<START>': 1,
#  'colors': 927,
#  'toilet': 83,
#  'tall': 200,
#  'salad': 469,
#  'have': 449,
#  'stand': 199,
#  'sleeping': 406,
#  'assortment': 789,
#  'suitcase': 381,
#  'clocks': 800,
#  'oranges': 434,
#  'polar': 724,
#  'shower': 355,
#  'older': 431,
#  'vase': 204,
#  'her': 88,
#  'trees': 128,
#  'fighter': 925,
#  'sandwiches': 657,
#  'bottom': 890,
#  'bun': 802,
#  'cat': 51,
#  'cow': 267,
#  'tree': 133,
#  'kid': 445,
#  'still': 943,
#  'assorted': 834,
#  'wide': 879,
#  'area': 104,
#  'picture': 101,
#  'land': 842,
#  'pole': 275,
#  'resting': 482,
#  'edge': 523,
#  'swinging': 284,
#  'fruits': 468,
#  'left': 638,
#  'kinds': 956,
#  'photo': 162,
#  'surf': 311,
#  'stairs': 796,
#  'motorcycle': 131,
#  'sunny': 496,
#  'shelf': 471,
#  'apartment': 1003,
#  'wooded': 812,
#  'behind': 143,
#  'slice': 373,
#  'painting': 760,
#  'hand': 191,
#  'dirty': 633,
#  'flat': 689,
#  'something': 336,
#  'face': 358,
#  'of': 6,
#  'jet': 346,
#  'kites': 264,
#  'petting': 952,
#  'snowy': 246,
#  'making': 460,
#  'sand': 411,
#  'laying': 95,
#  'orange': 190,
#  'chicken': 652,
#  'suits': 935,
#  'decorative': 981,
#  'together': 153,
#  'stuffed': 232,
#  'was': 942,
#  'brick': 345,
#  'antique': 929,
#  'place': 631,
#  'placed': 549,
#  'cement': 753,
#  'wet': 568,
#  'walks': 419,
#  'he': 378,
#  'one': 107,
#  'perched': 572,
#  'ball': 75,
#  'mouth': 375,
#  'many': 136,
#  'colored': 425,
#  'fridge': 680,
#  'that': 26,
#  'eats': 804,
#  'stall': 815,
#  '<END>': 2,
#  'trail': 756,
#  'race': 857,
#  'feeding': 629,
#  'sidewalk': 195,
#  'child': 155,
#  'carrying': 327,
#  'motorcycles': 324,
#  'jumping': 280,
#  'reaching': 694,
#  'skier': 353,
#  'some': 30,
#  'stands': 167,
#  'hydrant': 179,
#  'through': 105,
#  'very': 142,
#  'landing': 838,
#  'front': 41,
#  'pillows': 685,
#  'bananas': 211,
#  'clouds': 837,
#  'types': 583,
#  'cellphone': 538,
#  'pair': 276,
#  'surfboard': 158,
#  'photograph': 444,
#  'things': 833,
#  'prepared': 975,
#  'catcher': 567,
#  'players': 329,
#  'photos': 910,
#  'ear': 901,
#  'as': 124,
#  'meat': 343,
#  'dock': 675,
#  'eyes': 836,
#  'staring': 727,
#  'lawn': 792,
#  'plants': 630,
#  'rocks': 470,
#  'partially': 961,
#  'closed': 866,
#  'taking': 233,
#  'can': 456,
#  'track': 289,
#  'pan': 489,
#  'potatoes': 725,
#  'distance': 598,
#  'floors': 839,
#  'jumps': 811,
#  'hair': 459,
#  'slices': 531,
#  'same': 773,
#  'animals': 298,
#  'colorful': 299,
#  'cups': 826,
#  'reflection': 772,
#  'mountains': 514,
#  'containing': 640,
#  'helmet': 521,
#  'walkway': 914,
#  'apples': 467,
#  'tv': 297,
#  'forest': 427,
#  'tray': 380,
#  'appears': 922,
#  'single': 588,
#  'ocean': 173,
#  'pot': 676,
#  'boats': 295,
#  'sea': 907,
#  'it': 31,
#  'herd': 263,
#  'display': 258,
#  'boards': 569,
#  'or': 540,
#  'eggs': 846,
#  'boy': 79,
#  'nearby': 682,
#  'tricks': 611,
#  'outfit': 998,
#  'number': 393,
#  'been': 502,
#  'dry': 709,
#  'all': 317,
#  'busy': 366,
#  'rock': 529,
#  'pastries': 885,
#  'trailer': 863,
#  'loaded': 928,
#  'see': 853,
#  'line': 365,
#  'hotel': 587,
#  'about': 350,
#  'construction': 862,
#  'bread': 439,
#  'mouse': 437,
#  'sink': 117,
#  'drink': 464,
#  'path': 548,
#  'plays': 706,
#  'neck': 673,
#  'pasta': 906,
#  'woman': 23,
#  'graffiti': 643,
#  'tie': 216,
#  'steam': 973,
#  'professional': 726,
#  'the': 7,
#  'woods': 619,
#  'zoo': 395,
#  'doughnut': 560,
#  'cup': 334,
#  'outdoors': 761,
#  'crowd': 301,
#  'car': 129,
#  'striped': 674,
#  'skateboarder': 330,
#  'another': 187,
#  'view': 172,
#  'spoon': 758,
#  'topped': 302,
#  'lying': 368,
#  'rest': 944,
#  'get': 788,
#  'lit': 483,
#  'furniture': 436,
#  'talking': 278,
#  'drinks': 642,
#  'modern': 592,
#  'horse': 111,
#  'hitting': 474,
#  'sinks': 704,
#  'toppings': 595,
#  'stopped': 526,
#  'games': 771,
#  'giraffe': 119,
#  'windows': 501,
#  'urban': 902,
#  'women': 186,
#  'piece': 238,
#  'door': 296,
#  'hit': 309,
#  'features': 958,
#  'mountain': 261,
#  'teddy': 181,
#  'pasture': 632,
#  'arranged': 868,
#  'parked': 66,
#  'birds': 312,
#  'adult': 429,
#  'big': 168,
#  'little': 145,
#  'pizzas': 578,
#  'across': 242,
#  'inside': 160,
#  'traveling': 305,
#  'christmas': 757,
#  'chips': 897,
#  'down': 32,
#  'tour': 923,
#  'bed': 74,
#  'curtain': 873,
#  'full': 219,
#  'shown': 386,
#  'railroad': 639,
#  'winter': 969,
#  'next': 21,
#  'attached': 448,
#  'walls': 484,
#  'eat': 543,
#  'bowls': 600,
#  'street': 25,
#  'cluttered': 774,
#  'tub': 414,
#  'outdoor': 446,
#  'city': 84,
#  'commuter': 974,
#  'mirror': 182,
#  'table': 24,
#  'wave': 196,
#  'pile': 418,
#  'boat': 166,
#  'church': 705,
#  'head': 235,
#  'book': 371,
#  'out': 87,
#  'racket': 207,
#  'sign': 59,
#  'mans': 904,
#  'tarmac': 577,
#  'pulling': 384,
#  'girl': 96,
#  'dogs': 314,
#  'showing': 413,
#  'between': 416,
#  'she': 679,
#  'floor': 197,
#  'kneeling': 870,
#  'against': 321,
#  'guys': 596,
#  'lays': 745,
#  'at': 18,
#  'man': 12,
#  'away': 714,
#  'work': 723,
#  'clear': 524,
#  'skis': 156,
#  'friends': 861,
#  'trick': 279,
#  'mid': 809,
#  'three': 78,
#  'fish': 830,
#  'swing': 438,
#  'station': 229,
#  'their': 102,
#  'metal': 348,
#  'railing': 988,
#  'ride': 533,
#  'leash': 947,
#  'surfing': 377,
#  'flies': 636,
#  'sandy': 556,
#  'someone': 363,
#  'base': 535,
#  'different': 193,
#  'low': 793,
#  'wall': 137,
#  'dinner': 571,
#  'decorated': 415,
#  'streets': 991,
#  'someones': 860,
#  'french': 777,
#  'serve': 748,
#  'restroom': 831,
#  'pieces': 553,
#  'blue': 60,
#  'town': 575,
#  'wrapped': 941,
#  'bar': 661,
#  'chair': 170,
#  'enjoying': 594,
#  'airplane': 164,
#  'walk': 342,
#  'coming': 458,
#  'snowboarding': 835,
#  'vehicles': 712,
#  'teeth': 499,
#  'skating': 851,
#  'foods': 717,
#  'fireplace': 659,
#  'center': 655,
#  'stone': 486,
#  'vegetable': 884,
#  'large': 29,
#  'nice': 545,
#  'several': 94,
#  'soccer': 304,
#  'brushing': 570,
#  'scissors': 388,
#  'sits': 98,
#  'living': 122,
#  'banana': 320,
#  'under': 147,
#  'umbrellas': 281,
#  'computers': 551,
#  'has': 54,
#  'papers': 986,
#  'kitchen': 62,
#  'zebra': 183,
#  'well': 667,
#  'train': 45,
#  'drawn': 813,
#  'atop': 703,
#  'dirt': 220,
#  'scooter': 949,
#  'pitcher': 609,
#  'benches': 608,
#  'rug': 806,
#  'lap': 586,
#  'zebras': 215,
#  'phones': 617,
#  'empty': 277,
#  'various': 303,
#  'docked': 787,
#  'racquet': 359,
#  'buildings': 266,
#  'setting': 504,
#  'gathered': 607,
#  'police': 517,
#  'stainless': 832,
#  'toothbrush': 654,
#  'commercial': 721,
#  'contains': 959,
#  'skateboards': 691,
#  'wood': 318,
#  'watches': 593,
#  'planes': 664,
#  'fries': 490,
#  'cars': 202,
#  'getting': 306,
#  'seat': 441,
#  'night': 337,
#  'rainy': 999,
#  'bright': 498,
#  'during': 247,
#  'ramp': 354,
#  'while': 55,
#  'wedding': 805,
#  'farm': 1001,
#  'food': 61,
#  'takes': 687,
#  'controller': 544,
#  'does': 883,
#  'who': 313,
#  'rail': 525,
#  'corner': 271,
#  'cart': 562,
#  'him': 382,
#  'go': 798,
#  'skate': 241,
#  'space': 711,
#  'hold': 909,
#  'waves': 454,
#  'road': 85,
#  'smiling': 293,
#  'working': 507,
#  'pillow': 820,
#  'giraffes': 194,
#  'by': 50,
#  'closeup': 615,
#  'tied': 878,
#  'cattle': 635,
#  'few': 423,
#  'throw': 778,
#  'ties': 963,
#  'refrigerator': 252,
#  'pool': 775,
#  'running': 362,
#  'past': 440,
#  'and': 10,
#  'broccoli': 248,
#  'bike': 226,
#  'video': 300,
#  'trying': 516,
#  'field': 35,
#  'rice': 602,
#  'taken': 722,
#  'bench': 103,
#  'fancy': 926,
#  'fork': 465,
#  'pots': 889,
#  'six': 984,
#  'other': 70,
#  'candles': 626,
#  'arms': 825,
#  'bat': 157,
#  'middle': 222,
#  'putting': 708,
#  'men': 81,
#  'using': 310,
#  'bags': 653,
#  'apple': 473,
#  'produce': 1000,
#  'surface': 563,
#  'filled': 146,
#  'messy': 888,
#  'square': 768,
#  'catching': 698,
#  'bridge': 405,
#  'short': 940,
#  'breakfast': 754,
#  'poses': 720,
#  'pictures': 512,
#  'pretty': 610,
#  'hands': 361,
#  'shore': 559,
#  'riding': 46,
#  'desk': 127,
#  'hotdog': 803,
#  'subway': 746,
#  'towels': 886,
#  'served': 695,
#  'group': 34,
#  'body': 315,
#  'its': 114,
#  'blender': 785,
#  'parking': 205,
#  'beautiful': 515,
#  'which': 751,
#  'says': 854,
#  'park': 139,
#  'bunch': 171,
#  'bikes': 518,
#  'transit': 911,
#  'bathtub': 620,
#  'lot': 198,
#  'pedestrians': 966,
#  'overhead': 891,
#  'game': 92,
#  'couch': 169,
#  'air': 123,
#  'image': 225,
#  'hot': 269,
#  'shot': 541,
#  'onto': 452,
#  'hole': 960,
#  'leading': 970,
#  'run': 734,
#  'in': 8,
#  'pants': 920,
#  'steel': 668,
#  'nintendo': 584,
#  'snow': 73,
#  'pitch': 547,
#  'bottle': 385,
#  'towards': 487,
#  'intersection': 374,
#  'blanket': 500,
#  'birthday': 481,
#  'not': 742,
#  'carriage': 644,
#  'veggies': 915,
#  'painted': 485,
#  'meal': 420,
#  'flower': 497,
#  'towel': 715,
#  'beside': 243,
#  'engine': 603,
#  'driving': 230,
#  'dress': 530,
#  'lamp': 585,
#  'glass': 175,
#  'building': 71,
#  'tile': 669,
#  'cooked': 766,
#  'action': 933,
#  'monitors': 867,
#  'guy': 323,
#  'fence': 184,
#  'vehicle': 558,
#  'airplanes': 718,
#  'children': 274,
#  'umbrella': 130,
#  'kind': 882,
#  'half': 399,
#  'steps': 850,
#  'window': 126,
#  'box': 294,
#  'soup': 780,
#  'for': 80,
#  'clock': 91,
#  'store': 392,
#  'platform': 528,
#  'around': 106,
#  'kids': 412,
#  'doughnuts': 591,
#  'double': 272,
#  'baby': 206,
#  'screen': 390,
#  'bus': 64,
#  'plane': 180,
#  'control': 688,
#  'reading': 582,
#  'preparing': 372,
#  'his': 40,
#  'cabinet': 740,
#  'female': 478,
#  'doorway': 921,
#  'shirt': 189,
#  'shows': 546,
#  'lies': 964,
#  'an': 15,
#  'foot': 829,
#  'arm': 700,
#  'tomato': 985,
#  'party': 848,
#  'lady': 308,
#  'dressed': 369,
#  'dark': 398,
#  'slope': 228,
#  'lined': 424,
#  'hay': 741,
#  'silver': 417,
#  'military': 776,
#  'background': 159,
#  'ski': 265,
#  'tracks': 203,
#  'wearing': 89,
#  'concrete': 650,
#  'lettuce': 993,
#  'including': 671,
#  'black': 42,
#  'hat': 250,
#  'grey': 442,
#  'jacket': 401,
#  'pier': 982,
#  'gray': 389,
#  'back': 165,
#  'rider': 895,
#  'surfboards': 522,
#  'pie': 899,
#  'fire': 148,
#  'both': 692,
#  'skiing': 236,
#  'fashioned': 919,
#  'old': 144,
#  'two': 16,
#  'look': 402,
#  'traffic': 177,
#  'make': 955,
#  'picnic': 900,
#  'vintage': 647,
#  'clean': 510,
#  'wine': 237,
#  'ceiling': 858,
#  'catch': 492,
#  'drinking': 461,
#  'high': 351,
#  'rack': 699,
#  'plant': 581,
#  'small': 37,
#  'container': 702,
#  'tan': 874,
#  'right': 645,
#  'sandwich': 188,
#  'wire': 755,
#  'meter': 480,
#  'skateboarding': 537,
#  'fly': 662,
#  'person': 28,
#  'toys': 924,
#  'bite': 896,
#  'rain': 495,
#  'four': 234,
#  'day': 218,
#  'flying': 82,
#  'bear': 100,
#  'beds': 684,
#  'cream': 731,
#  'near': 38,
#  'walking': 56,
#  'bowl': 161,
#  'brown': 112,
#  '<UNK>': 3,
#  'cows': 240,
#  'umpire': 781,
#  'bow': 979,
#  'smiles': 743,
#  'up': 36,
#  'tomatoes': 690,
#  'holds': 259,
#  'green': 68,
#  'style': 732,
#  'flowers': 201,
#  'glasses': 254,
#  'net': 918,
#  'displayed': 451,
#  'buses': 422,
#  'row': 409,
#  'object': 937,
#  'books': 508,
#  'curb': 634,
#  'rackets': 818,
#  'lone': 736,
#  'five': 622,
#  'plastic': 491,
#  'tower': 217,
#  'school': 663,
#  'cage': 887,
#  'shoes': 660,
#  'desert': 852,
#  'mother': 735,
#  'multiple': 606,
#  'held': 957,
#  'cute': 623,
#  'cakes': 859,
#  'baked': 950,
#  'statue': 539,
#  'hillside': 794,
#  'type': 876,
#  'trucks': 599,
#  'are': 20,
#  'boxes': 677,
#  'houses': 946,
#  'carrot': 951,
#  'laptop': 108,
#  'wooden': 99,
#  'skies': 817,
#  'shaped': 716,
#  'elephant': 140,
#  'each': 134,
#  'camera': 268,
#  'is': 11,
#  'boarding': 786,
#  'appliances': 612,
#  'ice': 841,
#  'court': 152,
#  'kite': 154,
#  'like': 376,
#  'open': 132,
#  'decker': 357,
#  'country': 565,
#  'family': 566,
#  'others': 580,
#  'case': 561,
#  'cross': 494,
#  'office': 477,
#  'room': 44,
#  'residential': 996,
#  'ready': 223,
#  'clothing': 938,
#  'skiers': 432,
#  'dining': 462,
#  'bicycles': 713,
#  'trunk': 686,
#  'where': 739,
#  'ship': 976,
#  'seated': 784,
#  'river': 335,
#  'doors': 849,
#  'toward': 769,
#  'boys': 430,
#  'cheese': 326,
#  'cutting': 270,
#  'stack': 1002,
#  'coffee': 319,
#  'cooking': 576,
#  'reads': 905,
#  'facing': 822,
#  'swimming': 797,
#  'couple': 77,
#  'signs': 231,
#  'gear': 628,
#  'bird': 178,
#  'below': 649,
#  'snowboard': 344,
#  'huge': 683,
#  'motor': 555,
#  'after': 651,
#  'passing': 557,
#  'enclosure': 396,
#  'plain': 939,
#  'pastry': 965,
#  'pizza': 67,
#  'sale': 894,
#  'pond': 893,
#  'chocolate': 450,
#  'yard': 534,
#  'cap': 995,
#  'cut': 379,
#  'match': 656,
#  'signal': 930,
#  'what': 972,
#  'home': 347,
#  'television': 290,
#  'kitten': 847,
#  'grassy': 213,
#  'flag': 808,
#  'microwave': 408,
#  'market': 488,
#  'skateboard': 86,
#  'truck': 125,
#  'carrots': 404,
#  'there': 65,
#  'ground': 208,
#  'cloudy': 443,
#  'toy': 426,
#  'moving': 519,
#  'rides': 383,
#  'post': 625,
#  'equipment': 693,
#  'grill': 954,
#  'runway': 325,
#  'fresh': 624,
#  'blurry': 967,
#  'desktop': 821,
#  'shorts': 750,
#  'no': 479,
#  'them': 253,
#  'officer': 992,
#  'pose': 719,
#  'couches': 765,
#  'leaning': 455,
#  'sit': 227,
#  'bath': 532,
#  'light': 174,
#  'suit': 260,
#  'going': 273,
#  'hill': 224,
#  'business': 782,
#  'phone': 115,
#  'sitting': 14,
#  'to': 13,
#  'cats': 453,
#  'being': 209,
#  'uniform': 513,
#  'player': 90,
#  'boarder': 872,
#  'glove': 844,
#  'garden': 799,
#  'made': 387,
#  'keyboard': 283,
#  'grass': 63,
#  'floating': 701,
#  'take': 648,
#  'opened': 990,
#  'sky': 150,
#  'ledge': 814,
#  'variety': 601,
#  'this': 141,
#  'fenced': 641,
#  'shelves': 810,
#  'laptops': 590,
#  'highway': 763,
#  'outside': 121,
#  'stacked': 762,
#  'electric': 983,
#  'event': 828,
#  'grazing': 244,
#  'dishes': 729,
#  'toilets': 908,
#  'frisbee': 120,
#  'bicycle': 349,
#  'show': 759,
#  'eaten': 564,
#  'top': 33,
#  'holding': 27,
#  'device': 917,
#  'controllers': 790,
#  'looking': 72,
#  'lights': 340,
#  'play': 407,
#  'prepares': 738,
#  'used': 987,
#  'swings': 770,
#  'drives': 783,
#  'luggage': 245,
#  'from': 97,
#  'with': 9,
#  'covered': 135,
#  'fruit': 262,
#  'wii': 251,
#  'beer': 616,
#  'on': 5,
#  'serving': 733,
#  'close': 138,
#  'foreground': 912,
#  'pen': 618,
#  'electronic': 864,
#  'brush': 646,
#  'performing': 605,
#  'above': 239,
#  'elephants': 212,
#  'van': 801,
#  'bedroom': 331,
#  'new': 875,
#  'sheep': 163,
#  ...}

# %% [markdown]
# ## Look at the data
# It is always a good idea to look at examples from the dataset before working with it.
#
# You can use the `sample_coco_minibatch` function from the file `cs231n/coco_utils.py` to sample minibatches of data from the data structure returned from `load_coco_data`. Run the following to sample a small minibatch of training data and show the images and their captions. Running it multiple times and looking at the results helps you to get a sense of the dataset.
#
# Note that we decode the captions using the `decode_captions` function and that we download the images on-the-fly using their Flickr URL, so **you must be connected to the internet to view images**.

# %%
# Sample a minibatch and show the images and captions
batch_size = 3

captions, features, urls = sample_coco_minibatch(data, batch_size=batch_size)

# %%
for i, (caption, url) in enumerate(zip(captions, urls)):
    plt.imshow(image_from_url(url))
    plt.axis('off')
    caption_str = decode_captions(caption, data['idx_to_word'])
    plt.title(caption_str)
    plt.show()

# %% [markdown]
# # Recurrent Neural Networks
# As discussed in lecture, we will use recurrent neural network (RNN) language models for image captioning. The file `cs231n/rnn_layers.py` contains implementations of different layer types that are needed for recurrent neural networks, and the file `cs231n/classifiers/rnn.py` uses these layers to implement an image captioning model.
#
# We will first implement different types of RNN layers in `cs231n/rnn_layers.py`.

# %% [markdown]
# # Vanilla RNN: step forward
# Open the file `cs231n/rnn_layers.py`. This file implements the forward and backward passes for different types of layers that are commonly used in recurrent neural networks.
#
# First implement the function `rnn_step_forward` which implements the forward pass for a single timestep of a vanilla recurrent neural network. After doing so run the following to check your implementation. You should see errors less than 1e-8.

# %%
N, D, H = 3, 10, 4

x = np.linspace(-0.4, 0.7, num=N*D).reshape(N, D)
prev_h = np.linspace(-0.2, 0.5, num=N*H).reshape(N, H)
Wx = np.linspace(-0.1, 0.9, num=D*H).reshape(D, H)
Wh = np.linspace(-0.3, 0.7, num=H*H).reshape(H, H)
b = np.linspace(-0.2, 0.4, num=H)

next_h, _ = rnn_step_forward(x, prev_h, Wx, Wh, b)
expected_next_h = np.asarray([
  [-0.58172089, -0.50182032, -0.41232771, -0.31410098],
  [ 0.66854692,  0.79562378,  0.87755553,  0.92795967],
  [ 0.97934501,  0.99144213,  0.99646691,  0.99854353]])

print('next_h error: ', rel_error(expected_next_h, next_h))
# Out:
# next_h error:  6.29242142647e-09

# %% [markdown]
# # Vanilla RNN: step backward
# In the file `cs231n/rnn_layers.py` implement the `rnn_step_backward` function. After doing so run the following to numerically gradient check your implementation. You should see errors less than `1e-8`.

# %%
from cs231n.rnn_layers import rnn_step_forward, rnn_step_backward
np.random.seed(231)
N, D, H = 4, 5, 6
x = np.random.randn(N, D)
h = np.random.randn(N, H)
Wx = np.random.randn(D, H)
Wh = np.random.randn(H, H)
b = np.random.randn(H)

out, cache = rnn_step_forward(x, h, Wx, Wh, b)

dnext_h = np.random.randn(*out.shape)

fx = lambda x: rnn_step_forward(x, h, Wx, Wh, b)[0]
fh = lambda prev_h: rnn_step_forward(x, h, Wx, Wh, b)[0]
fWx = lambda Wx: rnn_step_forward(x, h, Wx, Wh, b)[0]
fWh = lambda Wh: rnn_step_forward(x, h, Wx, Wh, b)[0]
fb = lambda b: rnn_step_forward(x, h, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dnext_h)
dprev_h_num = eval_numerical_gradient_array(fh, h, dnext_h)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dnext_h)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dnext_h)
db_num = eval_numerical_gradient_array(fb, b, dnext_h)

dx, dprev_h, dWx, dWh, db = rnn_step_backward(dnext_h, cache)
# print('dx ={}, dprev_h ={},dWx ={},dWh ={},db ={}'.format(dx, dprev_h, dWx, dWh, db))
print('dx error: ', rel_error(dx_num, dx))
print('dprev_h error: ', rel_error(dprev_h_num, dprev_h))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  2.31993237231e-10
# dprev_h error:  2.68283556458e-10
# dWx error:  8.82024445424e-10
# dWh error:  4.70328755456e-10
# db error:  1.59568955262e-11

# %% [markdown]
# # Vanilla RNN: forward
# Now that you have implemented the forward and backward passes for a single timestep of a vanilla RNN, you will combine these pieces to implement a RNN that process an entire sequence of data.
#
# In the file `cs231n/rnn_layers.py`, implement the function `rnn_forward`. This should be implemented using the `rnn_step_forward` function that you defined above. After doing so run the following to check your implementation. You should see errors less than `1e-7`.

# %%
N, T, D, H = 2, 3, 4, 5

x = np.linspace(-0.1, 0.3, num=N*T*D).reshape(N, T, D)
h0 = np.linspace(-0.3, 0.1, num=N*H).reshape(N, H)
Wx = np.linspace(-0.2, 0.4, num=D*H).reshape(D, H)
Wh = np.linspace(-0.4, 0.1, num=H*H).reshape(H, H)
b = np.linspace(-0.7, 0.1, num=H)

h, _ = rnn_forward(x, h0, Wx, Wh, b)
expected_h = np.asarray([
  [
    [-0.42070749, -0.27279261, -0.11074945,  0.05740409,  0.22236251],
    [-0.39525808, -0.22554661, -0.0409454,   0.14649412,  0.32397316],
    [-0.42305111, -0.24223728, -0.04287027,  0.15997045,  0.35014525],
  ],
  [
    [-0.55857474, -0.39065825, -0.19198182,  0.02378408,  0.23735671],
    [-0.27150199, -0.07088804,  0.13562939,  0.33099728,  0.50158768],
    [-0.51014825, -0.30524429, -0.06755202,  0.17806392,  0.40333043]]])
print('h error: ', rel_error(expected_h, h))
# Out:
# h error:  7.72846615101e-08

# %% [markdown]
# # Vanilla RNN: backward
# In the file `cs231n/rnn_layers.py`, implement the backward pass for a vanilla RNN in the function `rnn_backward`. This should run back-propagation over the entire sequence, calling into the `rnn_step_backward` function that you defined above. You should see errors less than 5e-7.

# %%
np.random.seed(231)

N, D, T, H = 2, 3, 10, 5

x = np.random.randn(N, T, D)
h0 = np.random.randn(N, H)
Wx = np.random.randn(D, H)
Wh = np.random.randn(H, H)
b = np.random.randn(H)

out, cache = rnn_forward(x, h0, Wx, Wh, b)

dout = np.random.randn(*out.shape)

dx, dh0, dWx, dWh, db = rnn_backward(dout, cache)

fx = lambda x: rnn_forward(x, h0, Wx, Wh, b)[0]
fh0 = lambda h0: rnn_forward(x, h0, Wx, Wh, b)[0]
fWx = lambda Wx: rnn_forward(x, h0, Wx, Wh, b)[0]
fWh = lambda Wh: rnn_forward(x, h0, Wx, Wh, b)[0]
fb = lambda b: rnn_forward(x, h0, Wx, Wh, b)[0]

dx_num = eval_numerical_gradient_array(fx, x, dout)
dh0_num = eval_numerical_gradient_array(fh0, h0, dout)
dWx_num = eval_numerical_gradient_array(fWx, Wx, dout)
dWh_num = eval_numerical_gradient_array(fWh, Wh, dout)
db_num = eval_numerical_gradient_array(fb, b, dout)

print('dx error: ', rel_error(dx_num, dx))
print('dh0 error: ', rel_error(dh0_num, dh0))
print('dWx error: ', rel_error(dWx_num, dWx))
print('dWh error: ', rel_error(dWh_num, dWh))
print('db error: ', rel_error(db_num, db))
# Out:
# dx error:  1.53806704051e-09
# dh0 error:  3.38273476647e-09
# dWx error:  7.21878504629e-09
# dWh error:  1.32185432829e-07
# db error:  1.54137542139e-10

# %% [markdown]
# # Word embedding: forward
# In deep learning systems, we commonly represent words using vectors. Each word of the vocabulary will be associated with a vector, and these vectors will be learned jointly with the rest of the system.
#
# In the file `cs231n/rnn_layers.py`, implement the function `word_embedding_forward` to convert words (represented by integers) into vectors. Run the following to check your implementation. You should see error around `1e-8`.

# %%
N, T, V, D = 2, 4, 5, 3

x = np.asarray([[0, 3, 1, 2], [2, 1, 0, 3]])
W = np.linspace(0, 1, num=V*D).reshape(V, D)

out, _ = word_embedding_forward(x, W)
expected_out = np.asarray([
 [[ 0.,          0.07142857,  0.14285714],
  [ 0.64285714,  0.71428571,  0.78571429],
  [ 0.21428571,  0.28571429,  0.35714286],
  [ 0.42857143,  0.5,         0.57142857]],
 [[ 0.42857143,  0.5,         0.57142857],
  [ 0.21428571,  0.28571429,  0.35714286],
  [ 0.,          0.07142857,  0.14285714],
  [ 0.64285714,  0.71428571,  0.78571429]]])

print('out error: ', rel_error(expected_out, out))
# Out:
# out error:  1.00000000947e-08

# %% [markdown]
# # Word embedding: backward
# Implement the backward pass for the word embedding function in the function `word_embedding_backward`. After doing so run the following to numerically gradient check your implementation. You should see errors less than `1e-11`.

# %%
np.random.seed(231)

N, T, V, D = 50, 3, 5, 6
x = np.random.randint(V, size=(N, T))
W = np.random.randn(V, D)

out, cache = word_embedding_forward(x, W)
dout = np.random.randn(*out.shape)
dW = word_embedding_backward(dout, cache)

f = lambda W: word_embedding_forward(x, W)[0]
dW_num = eval_numerical_gradient_array(f, W, dout)
print('x = {}'.format(x))
print('W = {}'.format(W))
print('out = {}'.format(out))
print('dout = {}'.format(dout))
print('dW = {}'.format(dW))
print('dW error: ', rel_error(dW, dW_num))
# Out:
# x = [[0 4 1]
#  [3 2 4]
#  [2 1 2]
#  [2 4 2]
#  [1 3 1]
#  [4 3 1]
#  [1 1 3]
#  [4 2 3]
#  [4 4 4]
#  [3 0 2]
#  [2 1 1]
#  [4 0 4]
#  [1 1 4]
#  [3 1 2]
#  [2 1 1]
#  [3 1 4]
#  [0 4 1]
#  [1 4 4]
#  [0 0 2]
#  [0 3 1]
#  [0 1 4]
#  [0 1 4]
#  [3 2 4]
#  [1 1 2]
#  [1 0 4]
#  [4 0 0]
#  [3 2 2]
#  [1 1 1]
#  [4 2 1]
#  [4 4 4]
#  [0 1 4]
#  [1 2 1]
#  [0 4 2]
#  [3 3 4]
#  [3 1 3]
#  [4 2 4]
#  [0 2 3]
#  [3 2 4]
#  [4 2 1]
#  [2 1 4]
#  [0 1 2]
#  [0 3 0]
#  [3 0 0]
#  [1 1 0]
#  [0 2 4]
#  [3 3 2]
#  [3 2 0]
#  [1 4 3]
#  [4 0 1]
#  [0 3 3]]
# W = [[ 0.7074647  -2.69820765 -0.13712213 -1.15367617 -0.83550545 -1.11438332]
